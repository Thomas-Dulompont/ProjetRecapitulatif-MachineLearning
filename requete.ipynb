# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Les identifiants d'authentification
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = '1025606486584c43af06c6b8dad41712'

# %%
# Configuration de l'authentification
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Requête pour récupérer les titres sortis en 2022
results = sp.search(q='year:2022', type='track', limit=50)

# %%
# Affichage des titres
for track in results['tracks']['items']:
    print(track['name'], '-', track['artists'][0]['name'])
# Out:
# Pas bête - Beendo Z
# DIE - Gazo
# Miss You - Oliver Tree
# AMBER - Zola
# FADE UP - ZEG P
# SNAP - Rosa Linn
# Tiki Taka - Vacra
# I'm Good (Blue) - David Guetta
# Urus - Favé
# Doja - Central Cee
# PETETE - Gambi
# J'ai tout su - Jul
# DESPECHÁ - ROSALÍA
# Fetty Wap - Maes
# Un jour je marierai un ange - Pierre de Maere
# TOUT VA BIEN (feat. Ninho & Naps) - Alonzo
# Lola - RK
# Gasolina (feat. Rsko) - Tiakola
# STAR WALKIN' (League of Legends Worlds Anthem) - Lil Nas X
# Calm Down (with Selena Gomez) - Rema
# LET GO - Central Cee
# Celestial - Ed Sheeran
# Mr. Ocho - SDM
# THE LONELIEST - Måneskin
# 10:35 - Tiësto
# Coco - Lorenzo
# Unholy (feat. Kim Petras) - Sam Smith
# Come Back Home - Sofia Carson
# Creepin' (with The Weeknd & 21 Savage) - Metro Boomin
# Coeur De Pirate - Damso
# Mambella - Lucenzo
# RAPPEL - Gazo
# Kings & Queens (feat. Shibui) - Boris Way
# Autobahn - SCH
# CP_009_ Évidemment - Orelsan
# À peu près - Lomepal
# I'm So Excited - Sound Of Legend
# ...

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2022&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7a35Zdc78bDXJv2vYf5hSO'},
#        'href': 'https://api.spotify.com/v1/artists/7a35Zdc78bDXJv2vYf5hSO',
#        'id': '7a35Zdc78bDXJv2vYf5hSO',
#        'name': 'Beendo Z',
#        'type': 'artist',
#        'uri': 'spotify:artist:7a35Zdc78bDXJv2vYf5hSO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
# ...

# %%
""" import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv

# The authentication credentials


# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Query tracks released in 2022
results = sp.search(q='year:2022', type='track', limit=50)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through the tracks and retrieve audio features
    for track in results['tracks']['items']:
        track_id = track['id']
        audio_features = sp.audio_features(track_id)[0]
        
        # Format the artist name as a string
        artists = ', '.join([artist['name'] for artist in track['artists']])
        
        # Create a dictionary with the audio features
        track_features = {
            'name': track['name'],
            'artists': artists,
            'year': track['album']['release_date'][:4], # Extract the year from the album release date
            'popularity': track['popularity'],
            'duration_ms': audio_features['duration_ms'],
            'key': audio_features['key'],
            'mode': audio_features['mode'],
            'time_signature': audio_features['time_signature'],
            'acousticness': audio_features['acousticness'],
            'danceability': audio_features['danceability'],
            'energy': audio_features['energy'],
            'instrumentalness': audio_features['instrumentalness'],
            'liveness': audio_features['liveness'],
            'loudness': audio_features['loudness'],
            'speechiness': audio_features['speechiness'],
            'valence': audio_features['valence'],
            'tempo': audio_features['tempo']
        }
        
        # Write the audio features to the CSV file
        writer.writerow(track_features)
 """
# Out:
# " import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nimport csv\n\n# The authentication credentials\n\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\nsp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)\n\n# Query tracks released in 2022\nresults = sp.search(q='year:2022', type='track', limit=50)\n\n# Define audio features to retrieve\nfeatures = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']\n\n# Create a new CSV file and write headers\nwith open('audio_features_2022.csv', 'w', newline='', encoding='utf-8') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheader()\n\n    # Loop through the tracks and retrieve audio features\n    for track in results['tracks']['it
# ...

# %%
""" import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv

# The authentication credentials


# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through the tracks and retrieve audio features
    offset = 0
    limit = 50
    total = None

    while total is None or offset < total:
        results = sp.search(q='year:2022', type='track', limit=limit, offset=offset)

        if total is None:
            total = results['tracks']['total']

        for track in results['tracks']['items']:
            track_id = track['id']
            audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None
            
            # Skip track if audio features could not be retrieved
            if audio_features is None:
                continue
            
            # Format the artist name as a string
            artists = ', '.join([artist['name'] for artist in track['artists']])
            
            # Create a dictionary with the audio features
            track_features = {
                'name': track['name'],
                'artists': artists,
                'year': track['album']['release_date'][:4], # Extract the year from the album release date
                'popularity': track['popularity'],
                'duration_ms': audio_features['duration_ms'],
                'key': audio_features['key'],
                'mode': audio_features['mode'],
                'time_signature': audio_features['time_signature'],
                'acousticness': audio_features['acousticness'],
                'danceability': audio_features['danceability'],
                'energy': audio_features['energy'],
                'instrumentalness': audio_features['instrumentalness'],
                'liveness': audio_features['liveness'],
                'loudness': audio_features['loudness'],
                'speechiness': audio_features['speechiness'],
                'valence': audio_features['valence'],
                'tempo': audio_features['tempo']
            }
            
            # Write the audio features to the CSV file
            writer.writerow(track_features)

        offset += limit
 """
# Out:
# " import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nimport csv\n\n# The authentication credentials\n\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\nsp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)\n\n# Define audio features to retrieve\nfeatures = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']\n\n# Create a new CSV file and write headers\nwith open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheader()\n\n    # Loop through the tracks and retrieve audio features\n    offset = 0\n    limit = 50\n    total = None\n\n    while total is None or offset < total:\n        results = sp.search(q='year:2
# ...

# %%
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv

# %%
""" 

# The authentication credentials

# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through the tracks and retrieve audio features
    limit = 50
    offset = 0
    total = None

    while total is None or offset < total:
        results = sp.search(q='year:2022', type='track', limit=limit, offset=offset)

        if total is None:
            total = results['tracks']['total']

        for track in results['tracks']['items']:
            track_id = track['id']
            audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None
            
            # Skip track if audio features could not be retrieved
            if audio_features is None:
                continue
            
            # Format the artist name as a string
            artists = ', '.join([artist['name'] for artist in track['artists']])
            
            # Create a dictionary with the audio features
            track_features = {
                'name': track['name'],
                'artists': artists,
                'year': track['album']['release_date'][:4], # Extract the year from the album release date
                'popularity': track['popularity'],
                'duration_ms': audio_features['duration_ms'],
                'key': audio_features['key'],
                'mode': audio_features['mode'],
                'time_signature': audio_features['time_signature'],
                'acousticness': audio_features['acousticness'],
                'danceability': audio_features['danceability'],
                'energy': audio_features['energy'],
                'instrumentalness': audio_features['instrumentalness'],
                'liveness': audio_features['liveness'],
                'loudness': audio_features['loudness'],
                'speechiness': audio_features['speechiness'],
                'valence': audio_features['valence'],
                'tempo': audio_features['tempo']
            }
            
            # Write the audio features to the CSV file
            writer.writerow(track_features)

        offset += limit

        # Wait for a few seconds to avoid being rate-limited
        time.sleep(1)
 """
# Out:
# " \n\n# The authentication credentials\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\nsp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)\n\n# Define audio features to retrieve\nfeatures = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']\n\n# Create a new CSV file and write headers\nwith open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheader()\n\n    # Loop through the tracks and retrieve audio features\n    limit = 50\n    offset = 0\n    total = None\n\n    while total is None or offset < total:\n        results = sp.search(q='year:2022', type='track', limit=limit, offset=offset)\n\n        if total is None:\n   
# ...

# %%
""" import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv
import time

# The authentication credentials
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = "1025606486584c43af06c6b8dad41712"

# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through the tracks and retrieve audio features
    limit = 50

    for i in range(0, 10000, limit):
        results = sp.search(q='year:2022', type='track', limit=limit, offset=i)

        for track in results['tracks']['items']:
            track_id = track['id']
            audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None
            
            # Skip track if audio features could not be retrieved
            if audio_features is None:
                continue
            
            # Format the artist name as a string
            artists = ', '.join([artist['name'] for artist in track['artists']])
            
            # Create a dictionary with the audio features
            track_features = {
                'name': track['name'],
                'artists': artists,
                'year': track['album']['release_date'][:4], # Extract the year from the album release date
                'popularity': track['popularity'],
                'duration_ms': audio_features['duration_ms'],
                'key': audio_features['key'],
                'mode': audio_features['mode'],
                'time_signature': audio_features['time_signature'],
                'acousticness': audio_features['acousticness'],
                'danceability': audio_features['danceability'],
                'energy': audio_features['energy'],
                'instrumentalness': audio_features['instrumentalness'],
                'liveness': audio_features['liveness'],
                'loudness': audio_features['loudness'],
                'speechiness': audio_features['speechiness'],
                'valence': audio_features['valence'],
                'tempo': audio_features['tempo']
            }
            
            # Write the audio features to the CSV file
            writer.writerow(track_features)

        # Wait for a few seconds to avoid being rate-limited
        time.sleep(1)
        print(i)
 """
# Out:
# ' import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nimport csv\nimport time\n\n# The authentication credentials\nCLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"\nCLIENT_SECRET = "1025606486584c43af06c6b8dad41712"\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\nsp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)\n\n# Define audio features to retrieve\nfeatures = [\'name\', \'artists\', \'year\', \'popularity\', \'duration_ms\', \'key\', \'mode\', \'time_signature\', \'acousticness\', \'danceability\', \'energy\', \'instrumentalness\', \'liveness\', \'loudness\', \'speechiness\', \'valence\', \'tempo\']\n\n# Create a new CSV file and write headers\nwith open(\'audio_features_2022.csv\', \'a\', newline=\'\', encoding=\'utf-8\') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheader()\n\n    # Loop through the tracks and retri
# ...

# %%
""" import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv
import time

# The authentication credentials
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = "1025606486584c43af06c6b8dad41712"

# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
access_token = client_credentials_manager.get_access_token()['access_token']
sp = spotipy.Spotify(auth=access_token)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through each month of the year 2022 and retrieve tracks released in that month
    for month in range(1, 13):
        limit = 50
        offset = 0
        query = f'year:2022 AND month:{month}'

        while True:
            try:
                results = sp.search(q=query, type='track', limit=limit, offset=offset)

                if not results['tracks']['items']:
                    break

                for track in results['tracks']['items']:
                    track_id = track['id']
                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None

                    # Skip track if audio features could not be retrieved
                    if audio_features is None:
                        continue

                    # Format the artist name as a string
                    artists = ', '.join([artist['name'] for artist in track['artists']])

                    # Create a dictionary with the audio features
                    track_features = {
                        'name': track['name'],
                        'artists': artists,
                        'year': track['album']['release_date'][:4],  # Extract the year from the album release date
                        'popularity': track['popularity'],
                        'duration_ms': audio_features['duration_ms'],
                        'key': audio_features['key'],
                        'mode': audio_features['mode'],
                        'time_signature': audio_features['time_signature'],
                        'acousticness': audio_features['acousticness'],
                        'danceability': audio_features['danceability'],
                        'energy': audio_features['energy'],
                        'instrumentalness': audio_features['instrumentalness'],
                        'liveness': audio_features['liveness'],
                        'loudness': audio_features['loudness'],
                        'speechiness': audio_features['speechiness'],
                        'valence': audio_features['valence'],
                        'tempo': audio_features['tempo']
                    }

                    # Write the audio features to the CSV file
                    writer.writerow(track_features)

                # Wait for a few seconds to avoid being rate-limited
                time.sleep(1)

                # Update the offset
                offset += limit
            except spotipy.SpotifyException as e:
                if e.http_status == 401:
                    access_token = client_credentials_manager.get_access_token()['access_token']  # Get a new access token
                else:
                    raise e
 """
# Out:
# ' import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nimport csv\nimport time\n\n# The authentication credentials\nCLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"\nCLIENT_SECRET = "1025606486584c43af06c6b8dad41712"\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\naccess_token = client_credentials_manager.get_access_token()[\'access_token\']\nsp = spotipy.Spotify(auth=access_token)\n\n# Define audio features to retrieve\nfeatures = [\'name\', \'artists\', \'year\', \'popularity\', \'duration_ms\', \'key\', \'mode\', \'time_signature\', \'acousticness\', \'danceability\', \'energy\', \'instrumentalness\', \'liveness\', \'loudness\', \'speechiness\', \'valence\', \'tempo\']\n\n# Create a new CSV file and write headers\nwith open(\'audio_features_2022.csv\', \'a\', newline=\'\', encoding=\'utf-8\') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheader(
# ...

# %%
""" import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv
import time

# The authentication credentials
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = "1025606486584c43af06c6b8dad41712"


# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
access_token = client_credentials_manager.get_access_token()['access_token']
sp = spotipy.Spotify(auth=access_token)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through the months of the year and retrieve audio features
    for month in range(1, 13):
        limit = 50
        offset = 0
        query = f'year:2022 AND month:{month}'

        while offset < 1000:
            try:
                results = sp.search(q=query,
                                     type='track',
                                     limit=limit,
                                     offset=offset,
                                     )

                for track in results['tracks']['items']:
                    track_id = track['id']
                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None

                    # Skip track if audio features could not be retrieved
                    if audio_features is None:
                        continue

                    # Format the artist name as a string
                    artists = ', '.join([artist['name'] for artist in track['artists']])

                    # Create a dictionary with the audio features
                    track_features = {
                        'name': track['name'],
                        'artists': artists,
                        'year': track['album']['release_date'][:4],  # Extract the year from the album release date
                        'popularity': track['popularity'],
                        'duration_ms': audio_features['duration_ms'],
                        'key': audio_features['key'],
                        'mode': audio_features['mode'],
                        'time_signature': audio_features['time_signature'],
                        'acousticness': audio_features['acousticness'],
                        'danceability': audio_features['danceability'],
                        'energy': audio_features['energy'],
                        'instrumentalness': audio_features['instrumentalness'],
                        'liveness': audio_features['liveness'],
                        'loudness': audio_features['loudness'],
                        'speechiness': audio_features['speechiness'],
                        'valence': audio_features['valence'],
                        'tempo': audio_features['tempo']
                    }

                    # Write the audio features to the CSV file
                    writer.writerow(track_features)

                # Wait for a few seconds to avoid being rate-limited
                time.sleep(1)

                # Update the offset
                offset += limit

            except spotipy.SpotifyException as e:
                if e.http_status == 401:
                    access_token = client_credentials_manager.get_access_token()['access_token']  # Get a new access token
                else:
                    raise e
 """
# Out:
# ' import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nimport csv\nimport time\n\n# The authentication credentials\nCLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"\nCLIENT_SECRET = "1025606486584c43af06c6b8dad41712"\n\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\naccess_token = client_credentials_manager.get_access_token()[\'access_token\']\nsp = spotipy.Spotify(auth=access_token)\n\n# Define audio features to retrieve\nfeatures = [\'name\', \'artists\', \'year\', \'popularity\', \'duration_ms\', \'key\', \'mode\', \'time_signature\', \'acousticness\', \'danceability\', \'energy\', \'instrumentalness\', \'liveness\', \'loudness\', \'speechiness\', \'valence\', \'tempo\']\n\n# Create a new CSV file and write headers\nwith open(\'audio_features_2022.csv\', \'a\', newline=\'\', encoding=\'utf-8\') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheade
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# The authentication credentials


# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Get the list of available genres for recommendations
genres = sp.recommendation_genre_seeds()['genres']

# Print the list of genres
print(genres)
# Out:
# ['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-
# ...

# %%
""" import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import csv
import time

# The authentication credentials
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = "1025606486584c43af06c6b8dad41712"


# Configure authentication
client_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
access_token = client_credentials_manager.get_access_token()['access_token']
sp = spotipy.Spotify(auth=access_token)

# Define audio features to retrieve
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo']

# Create a new CSV file and write headers
with open('audio_features_2022.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through the months of the year and retrieve audio features
    for month in range(1, 13):
        limit = 50
        offset = 0
        query = f'year:2022 AND month:{month}'

        while offset < 1000:
            try:
                results = sp.search(q=query,
                                     type='track',
                                     limit=limit,
                                     offset=offset,
                                     )

                for track in results['tracks']['items']:
                    track_id = track['id']
                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None

                    # Skip track if audio features could not be retrieved
                    if audio_features is None:
                        continue

                    # Format the artist name as a string
                    artists = ', '.join([artist['name'] for artist in track['artists']])

                    # Create a dictionary with the audio features
                    track_features = {
                        'name': track['name'],
                        'artists': artists,
                        'year': track['album']['release_date'][:4],  # Extract the year from the album release date
                        'popularity': track['popularity'],
                        'duration_ms': audio_features['duration_ms'],
                        'key': audio_features['key'],
                        'mode': audio_features['mode'],
                        'time_signature': audio_features['time_signature'],
                        'acousticness': audio_features['acousticness'],
                        'danceability': audio_features['danceability'],
                        'energy': audio_features['energy'],
                        'instrumentalness': audio_features['instrumentalness'],
                        'liveness': audio_features['liveness'],
                        'loudness': audio_features['loudness'],
                        'speechiness': audio_features['speechiness'],
                        'valence': audio_features['valence'],
                        'tempo': audio_features['tempo']
                    }

                    # Write the audio features to the CSV file
                    writer.writerow(track_features)

                # Wait for a few seconds to avoid being rate-limited
                time.sleep(1)

                # Update the offset
                offset += limit

            except spotipy.SpotifyException as e:
                if e.http_status == 401:
                    access_token = client_credentials_manager.get_access_token()['access_token']  # Get a new access token
                else:
                    raise e
 """
# Out:
# ' import spotipy\nfrom spotipy.oauth2 import SpotifyClientCredentials\nimport csv\nimport time\n\n# The authentication credentials\nCLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"\nCLIENT_SECRET = "1025606486584c43af06c6b8dad41712"\n\n\n# Configure authentication\nclient_credentials_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)\naccess_token = client_credentials_manager.get_access_token()[\'access_token\']\nsp = spotipy.Spotify(auth=access_token)\n\n# Define audio features to retrieve\nfeatures = [\'name\', \'artists\', \'year\', \'popularity\', \'duration_ms\', \'key\', \'mode\', \'time_signature\', \'acousticness\', \'danceability\', \'energy\', \'instrumentalness\', \'liveness\', \'loudness\', \'speechiness\', \'valence\', \'tempo\']\n\n# Create a new CSV file and write headers\nwith open(\'audio_features_2022.csv\', \'a\', newline=\'\', encoding=\'utf-8\') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheade
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# Define your app credentials
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = "1025606486584c43af06c6b8dad41712"
redirect_uri = 'http://localhost:8888/callback'

# Create an authentication manager
auth_manager = SpotifyOAuth(client_id=CLIENT_ID, client_secret=CLIENT_SECRET, redirect_uri=redirect_uri, scope='user-library-read')

# Get an access token
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
sp.auth_manager.get_access_token()
# Out:
# /tmp/ipykernel_6813/219757804.py:1: DeprecationWarning: You're using 'as_dict = True'.get_access_token will return the token string directly in future versions. Please adjust your code accordingly, or use get_cached_token instead.
#   sp.auth_manager.get_access_token()
# {'access_token': 'BQDMBuJdd3tyheIYCqNuNTmHM_mgqg6uK47Ey9cIOJSxm5o3ZpeecXXFNYz19tpnz22ePoINNtHiIKCXkfJFUu58UnTeF08wZBpMXjGv6PCqaLFYUmv607NSbmGpSNIVEdZhucyxi1RnlPehbYFmI43qmFm5eu628z_Akrc_Ja5q5XK-2-sV3S6cxqseNMP4elUcglOudahl-P3imWr_',
#  'token_type': 'Bearer',
#  'expires_in': 3600,
#  'refresh_token': 'AQAC2j8_5N1GSIwzJaZv5VVec9jafAj8ZyhFmckfRtYx2DnMONvm4_m-41CjdgFdow6QBKbXgSbLNZBvKdK3Ce-fVjK91AZLFlPvnH9SnAtwyMmrE5sOceVy8cBo-dhDGJA',
#  'scope': 'user-library-read',
#  'expires_at': 1677011295}

# %%
""" 
# Create a new CSV file and write headers
with open('audio_features_20221.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through each genre and retrieve audio features
    limit = 50
    offset = 0

    for genre in genres:
        limit = 50
        offset = 0
        query = f'year:2022 AND genre:{genre}'


        while offset < 1000:
            try:
                results = sp.search(q=query,
                                     type='track',
                                     limit=limit,
                                     offset=offset,
                                     )

                for track in results['tracks']['items']:
                    track_id = track['id']
                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None

                    # Skip track if audio features could not be retrieved
                    if audio_features is None:
                        print("None")
                        continue

                    # Format the artist name as a string
                    artists = ', '.join([artist['name'] for artist in track['artists']])

                    # Create a dictionary with the audio features
                    track_features = {
                        'name': track['name'],
                        'artists': artists,
                        'year': track['album']['release_date'][:4],  # Extract the year from the album release date
                        'popularity': track['popularity'],
                        'duration_ms': audio_features['duration_ms'],
                        'key': audio_features['key'],
                        'mode': audio_features['mode'],
                        'time_signature': audio_features['time_signature'],
                        'acousticness': audio_features['acousticness'],
                        'danceability': audio_features['danceability'],
                        'energy': audio_features['energy'],
                        'instrumentalness': audio_features['instrumentalness'],
                        'liveness': audio_features['liveness'],
                        'loudness': audio_features['loudness'],
                        'speechiness': audio_features['speechiness'],
                        'valence': audio_features['valence'],
                        'tempo': audio_features['tempo']
                    }

                    # Write the audio features to the CSV file
                    print(track_features)
                    writer.writerow(track_features)

                # Wait for a few seconds to avoid being rate-limited
                time.sleep(1)

                # Update the offset
                offset += limit
                

            except spotipy.SpotifyException as e:
                if e.http_status == 401:
                    print(e.http_status) #
            except:
                print ("2")
 """
# Out:
# ' \n# Create a new CSV file and write headers\nwith open(\'audio_features_20221.csv\', \'w\', newline=\'\', encoding=\'utf-8\') as file:\n    writer = csv.DictWriter(file, fieldnames=features)\n    writer.writeheader()\n\n    # Loop through each genre and retrieve audio features\n    limit = 50\n    offset = 0\n\n    for genre in genres:\n        limit = 50\n        offset = 0\n        query = f\'year:2022 AND genre:{genre}\'\n\n\n        while offset < 1000:\n            try:\n                results = sp.search(q=query,\n                                     type=\'track\',\n                                     limit=limit,\n                                     offset=offset,\n                                     )\n\n                for track in results[\'tracks\'][\'items\']:\n                    track_id = track[\'id\']\n                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None\n\n                    # Skip track if audio feature
# ...

# %%
features = ['name', 'artists', 'year', 'popularity', 'duration_ms', 'key', 'mode', 'time_signature', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence', 'tempo','genre']

# %%
""" 
# Create a new CSV file and write headers
with open('audio_features_2022_genre.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through each genre and retrieve audio features
    limit = 50
    offset = 0

    for genre in genres[:3]:
        limit = 50
        offset = 0
        query = f'year:2022 AND genre:{genre}'


        while offset < 1000:
            try:
                results = sp.search(q=query,
                                     type='track',
                                     limit=limit,
                                     offset=offset,
                                     )

                for track in results['tracks']['items']:
                    track_id = track['id']
                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None

                    # Skip track if audio features could not be retrieved
                    if audio_features is None:
                        print("None")
                        continue

                    # Format the artist name as a string
                    artists = ', '.join([artist['name'] for artist in track['artists']])

                    # Create a dictionary with the audio features
                    track_features = {
                        'name': track['name'],
                        'artists': artists,
                        'year': track['album']['release_date'],  # Extract the year from the album release date
                        'popularity': track['popularity'],
                        'duration_ms': audio_features['duration_ms'],
                        'key': audio_features['key'],
                        'mode': audio_features['mode'],
                        'time_signature': audio_features['time_signature'],
                        'acousticness': audio_features['acousticness'],
                        'danceability': audio_features['danceability'],
                        'energy': audio_features['energy'],
                        'instrumentalness': audio_features['instrumentalness'],
                        'liveness': audio_features['liveness'],
                        'loudness': audio_features['loudness'],
                        'speechiness': audio_features['speechiness'],
                        'valence': audio_features['valence'],
                        'tempo': audio_features['tempo']
                    }
                    track_features["genre"] = genre
                    # Write the audio features to the CSV file
                    print(track_features)
                    writer.writerow(track_features)

                # Wait for a few seconds to avoid being rate-limited
                time.sleep(1)

                # Update the offset
                offset += limit
                

            except spotipy.SpotifyException as e:
                if e.http_status == 401:
                    print(e.http_status) #
            except:
                print ("2")
 """

# %%
print(genres[:3])
# Out:
# ['acoustic', 'afrobeat', 'alt-rock']

# %%
# Create a new CSV file and write headers
with open('audio_features_2022_genre.csv', 'a', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=features)
    writer.writeheader()

    # Loop through each genre and retrieve audio features
    limit = 50
    offset = 0

    for genre in genres[3:30]:
        limit = 50
        offset = 0
        query = f'year:2022 AND genre:{genre}'


        while offset < 1000:
            try:
                results = sp.search(q=query,
                                     type='track',
                                     limit=limit,
                                     offset=offset,
                                     )

                for track in results['tracks']['items']:
                    track_id = track['id']
                    audio_features = sp.audio_features(track_id)[0] if sp.audio_features(track_id) else None

                    # Skip track if audio features could not be retrieved
                    if audio_features is None:
                        print("None")
                        continue

                    # Format the artist name as a string
                    artists = ', '.join([artist['name'] for artist in track['artists']])

                    # Create a dictionary with the audio features
                    track_features = {
                        'name': track['name'],
                        'artists': artists,
                        'year': track['album']['release_date'],  # Extract the year from the album release date
                        'popularity': track['popularity'],
                        'duration_ms': audio_features['duration_ms'],
                        'key': audio_features['key'],
                        'mode': audio_features['mode'],
                        'time_signature': audio_features['time_signature'],
                        'acousticness': audio_features['acousticness'],
                        'danceability': audio_features['danceability'],
                        'energy': audio_features['energy'],
                        'instrumentalness': audio_features['instrumentalness'],
                        'liveness': audio_features['liveness'],
                        'loudness': audio_features['loudness'],
                        'speechiness': audio_features['speechiness'],
                        'valence': audio_features['valence'],
                        'tempo': audio_features['tempo']
                    }
                    track_features["genre"] = genre
                    # Write the audio features to the CSV file
                    print(track_features)
                    writer.writerow(track_features)

                # Wait for a few seconds to avoid being rate-limited
                time.sleep(1)

                # Update the offset
                offset += limit
                

            except spotipy.SpotifyException as e:
                if e.http_status == 401:
                    print(e.http_status) #
            except:
                print ("2")

# %%
print(genres)
# Out:
# ['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-
# ...

# %%
print(genres[30:60])
# Out:
# ['dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop']

# %%
print(genres[60:len(genres)])
# Out:
# ['industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-pop', 'progressive-house', 'psych-rock', 'punk', 'punk-rock', 'r-n-b', 'rainy-day', 'reggae', 'reggaeton', 'road-trip', 'rock', 'rock-n-roll', 'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo', 'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter', 'soul', 'soundtracks', 'spanish', 'study', 'summer', 'swedish', 'synth-pop', 'tango', 'techno', 'trance', 'trip-hop', 'turkish', 'work-out', 'world-music']

# %%
print(genres)
# Out:
# ['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient', 'anime', 'black-metal', 'bluegrass', 'blues', 'bossanova', 'brazil', 'breakbeat', 'british', 'cantopop', 'chicago-house', 'children', 'chill', 'classical', 'club', 'comedy', 'country', 'dance', 'dancehall', 'death-metal', 'deep-house', 'detroit-techno', 'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm', 'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk', 'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove', 'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle', 'heavy-metal', 'hip-hop', 'holidays', 'honky-tonk', 'house', 'idm', 'indian', 'indie', 'indie-pop', 'industrial', 'iranian', 'j-dance', 'j-idol', 'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino', 'malay', 'mandopop', 'metal', 'metal-misc', 'metalcore', 'minimal-techno', 'movies', 'mpb', 'new-age', 'new-release', 'opera', 'pagode', 'party', 'philippines-opm', 'piano', 'pop', 'pop-film', 'post-dubstep', 'power-
# ...

# %%
CLIENT_ID = "266fb34a41c2418baa2fe7beabbc8d0e"
CLIENT_SECRET = "1025606486584c43af06c6b8dad41712"
